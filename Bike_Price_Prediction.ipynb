# %% [markdown]
# ### **Bike Price Prediction using Linear Regression**

# %% [markdown]
# **Import Library**

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# **Import CSV as DataFrame**

# %%
df = pd.read_csv(r'https://github.com/YBI-Foundation/Dataset/raw/main/Bike%20Prices.csv')

# %% [markdown]
# **Get the First Five Rows of DataFrame**

# %%
df.head()
# Out:
#    Brand               Model  Selling_Price  Year Seller_Type      Owner  \
# 0    TVS          TVS XL 100          30000  2017  Individual  1st owner
# 1  Bajaj       Bajaj  ct 100          18000  2017  Individual  1st owner
# 2     Yo            Yo Style          20000  2011  Individual  1st owner
# 3  Bajaj  Bajaj Discover 100          25000  2010  Individual  1st owner
# 4  Bajaj  Bajaj Discover 100          24999  2012  Individual  2nd owner
#
#    KM_Driven  Ex_Showroom_Price
# 0       8000            30490.0
# 1      35000            32000.0
# 2      10000            37675.0
# 3      43000            42859.0
# 4      35000            42859.0

# %% [markdown]
# **Get Information of DataFrame**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1061 entries, 0 to 1060
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Brand              1061 non-null   object
#  1   Model              1061 non-null   object
#  2   Selling_Price      1061 non-null   int64
#  3   Year               1061 non-null   int64
#  4   Seller_Type        1061 non-null   object
#  5   Owner              1061 non-null   object
#  6   KM_Driven          1061 non-null   int64
#  7   Ex_Showroom_Price  626 non-null    float64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 66.4+ KB

# %% [markdown]
# **Get Missing Values Drop**

# %%
df = df.dropna()

# %% [markdown]
# **Get Summary Statistics**

# %%
df.describe()
# Out:
#        Selling_Price         Year      KM_Driven  Ex_Showroom_Price
# count     626.000000   626.000000     626.000000       6.260000e+02
# mean    59445.164537  2014.800319   32671.576677       8.795871e+04
# std     59904.350888     3.018885   45479.661039       7.749659e+04
# min      6000.000000  2001.000000     380.000000       3.049000e+04
# 25%     30000.000000  2013.000000   13031.250000       5.485200e+04
# 50%     45000.000000  2015.000000   25000.000000       7.275250e+04
# 75%     65000.000000  2017.000000   40000.000000       8.703150e+04
# max    760000.000000  2020.000000  585659.000000       1.278000e+06

# %% [markdown]
# **Get Categories and Counts of Categorical Variables**

# %%
df[['Brand']].value_counts()
# Out:
# Brand
# Honda       170
# Bajaj       143
# Hero        108
# Yamaha       94
# Royal        40
# TVS          23
# Suzuki       18
# KTM           6
# Mahindra      6
# Kawasaki      4
# UM            3
# Activa        3
# Harley        2
# Vespa         2
# BMW           1
# Hyosung       1
# Benelli       1
# Yo            1
# dtype: int64

# %%
df[['Model']].value_counts()
# Out:
# Model
# Honda Activa [2000-2015]                      23
# Honda CB Hornet 160R                          22
# Bajaj Pulsar 180                              20
# Yamaha FZ S V 2.0                             16
# Bajaj Discover 125                            16
#                                               ..
# Royal Enfield Thunderbird 500                  1
# Royal Enfield Continental GT [2013 - 2018]     1
# Royal Enfield Classic Stealth Black            1
# Royal Enfield Classic Squadron Blue            1
# Yo Style                                       1
# Length: 183, dtype: int64

# %%
df[['Seller_Type']].value_counts()
# Out:
# Seller_Type
# Individual     623
# Dealer           3
# dtype: int64

# %%
df[['Owner']].value_counts()
# Out:
# Owner
# 1st owner    556
# 2nd owner     66
# 3rd owner      3
# 4th owner      1
# dtype: int64

# %% [markdown]
# **Get Column Names**

# %%
df.columns
# Out:
# Index(['Brand', 'Model', 'Selling_Price', 'Year', 'Seller_Type', 'Owner',
#        'KM_Driven', 'Ex_Showroom_Price'],
#       dtype='object')

# %% [markdown]
# **Get Shape of DataFrame**

# %%
df.shape
# Out:
# (626, 8)

# %% [markdown]
# **Get Encoding of Categorical Features**

# %%
df.replace({'Seller_Type':{'Individual':0,'Dealer':1}},inplace=True)

# %%
df.replace({'Owner':{'1st owner':0, '2nd owner':1,'3rd owner':2,'4th owner':3}},inplace=True)

# %% [markdown]
# **Define y(dependent or label or target varaible) and X(independent or features or attribute Variable)**

# %%
y=df['Selling_Price']

# %%
y.shape
# Out:
# (626,)

# %%
y
# Out:
# 0       30000
# 1       18000
# 2       20000
# 3       25000
# 4       24999
#         ...
# 621    330000
# 622    300000
# 623    425000
# 624    760000
# 625    750000
# Name: Selling_Price, Length: 626, dtype: int64

# %%
X=df[['Year','Seller_Type', 'Owner', 'KM_Driven', 'Ex_Showroom_Price']]

# %%
X.shape
# Out:
# (626, 5)

# %%
X
# Out:
#      Year  Seller_Type  Owner  KM_Driven  Ex_Showroom_Price
# 0    2017            0      0       8000            30490.0
# 1    2017            0      0      35000            32000.0
# 2    2011            0      0      10000            37675.0
# 3    2010            0      0      43000            42859.0
# 4    2012            0      1      35000            42859.0
# ..    ...          ...    ...        ...                ...
# 621  2014            0      3       6500           534000.0
# 622  2011            0      0      12000           589000.0
# 623  2017            0      1      13600           599000.0
# 624  2019            0      0       2800           752020.0
# 625  2013            0      1      12000          1278000.0
#
# [626 rows x 5 columns]

# %% [markdown]
# **Get Train Test Split**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test, y_train,y_test = train_test_split(X,y,test_size =0.3, random_state =12529)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((438, 5), (188, 5), (438,), (188,))

# %% [markdown]
# **Get Model Train**

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# **Get Model Prediction**

# %%
y_pred = lr.predict(X_test)

# %%
y_pred.shape
# Out:
# (188,)

# %%
y_pred
# Out:
# array([ 52652.60893422,  39486.41676173, 196562.43198627,  55580.50406346,
#         26140.7294817 ,  94608.16940208, 119187.31851385,  68882.36906449,
#         33660.46971131,  46944.42315338,  53461.39448307,  11010.80661867,
#         33332.52261297,  99136.85017253,  53520.69363006,  77889.92667438,
#         45898.51705698,  51568.32996292,  23936.19734581,  53169.07821731,
#         93240.71089046,   -982.05901743,  72782.26710892,  61648.18639175,
#         60975.53326568,  29005.69236304,  52733.45578054,  76744.27220675,
#         25899.12686653,  38977.3804656 , 136552.24672472,  43207.37077002,
#         59999.13518357, 178300.52079438,  56538.55902121,  21881.41938332,
#         39242.90242196,  32072.27344395,  54250.50343725,  39760.72648088,
#         58983.84447845,  30360.33221383,  53733.14061814,  39812.75115879,
#        135490.92768481,  44412.40326896,   7898.88343966,  52017.36847525,
#         42026.43374388, 104169.26650705,  60024.05156225, 101703.69488341,
#         73823.40634494,   7418.53528016,  28994.62378812,  26468.30379687,
#         58732.87189512,  24064.07758698,  22054.26970934,  96688.09028926,
#         49059.60157504, 149306.70799843,  35995.27887143,  56235.97097093,
#        155880.34537467, 103229.27553899, 118839.81801386,  -4400.37997653,
#         29439.79781322,  70995.09147177,  30768.12967082,  56391.4090252 ,
#         70106.66220846,  89098.33049166, 350498.8314442 ,  57599.65779778,
#         61284.42259901,  51994.07673427,  52266.05783202,  40936.60780955,
#         31783.57796447,  45235.90798598,  18126.24685077,  55728.83237426,
#        123106.08328162,  36957.36642606,  54105.13423638,  53106.19984882,
#         46915.53621663,  26975.12879393,  53457.41832248,  49221.50886948,
#        405104.57629207,  26408.33619491,  35114.81521371,  36983.34162713,
#         39544.33351173,  22170.10320934,  66661.33393213,  65221.83868648,
#         63184.58572117,   8219.81705319,  47459.79434852,  39363.94214107,
#         53737.34611386,  44086.30857564,  67095.51897299,  75758.2937595 ,
#        132086.83399626,  68670.00764783,  22145.56947711, 115599.13224033,
#         58947.47158093, 119492.34673052,  52789.15224477,  33853.85015862,
#         24614.59975479,  41758.07556629,  54716.5280832 ,  61963.51345742,
#         52911.14478891,  79992.53011007,  29672.22354318,  43025.2740096 ,
#         42464.2664845 ,  60340.66312892,  57087.75135542,  55532.76882004,
#         50834.66685811,  50064.17609668,  33777.58022366,  69345.63512726,
#         29407.05857674,  63759.75033494,  65697.08116447,   6868.42621987,
#        145514.8600303 ,  22423.07191623,  68523.77051707, -12076.4902054 ,
#         41944.35163782,  70727.85652738,  50548.08989733,  52879.93137833,
#         24235.53641315,  65257.46077037,  41925.69184498,  55972.52034755,
#         22054.26970934,  55214.21373799,  16299.47773725, 103976.21067372,
#         89730.41155838,  93124.87739046,  32629.09307002,  25510.96281861,
#         47409.12768996,  32270.96436232, 144891.06315564,  24503.8474359 ,
#         20472.25040594,  51752.80978892,  60363.44082617,  39539.28344413,
#         75319.87432593,  30491.06261343,  13752.49475224,  22966.27623803,
#         40682.7766261 ,  51692.0344388 ,  45360.47707562,  48355.62490679,
#         16922.07641166, 160218.4549236 , -13296.86796356,  38887.94367841,
#         93468.2384686 ,  24948.38574986,  60339.69784975,  60108.99612892,
#         52196.98997516,  64756.57564074,  25703.96236817,  88403.32949167,
#        122780.03432155, 107117.07767783,  75475.8751907 ,  31827.55654714])

# %% [markdown]
# **Get Model Evaluation**

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 280339916.8985716

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 11298.505848534247

# %%
r2_score(y_test, y_pred)
# Out:
# 0.8473238209281203

# %% [markdown]
# **Get Visualization of Actual Vs Predicted Results**

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test,y_pred)
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.title('Actual Price vs Predicted Price')
plt.show()

# %% [markdown]
# **Get Future Predictions**

# %%
df_new = df.sample(1)

# %%
df_new
# Out:
#     Brand              Model  Selling_Price  Year  Seller_Type  Owner  \
# 225  Hero  Hero Passion XPro          25000  2013            0      0
#
#      KM_Driven  Ex_Showroom_Price
# 225      25000            59640.0

# %%
df_new.shape
# Out:
# (1, 8)

# %%
X_new = df_new.drop(['Brand', 'Model', 'Selling_Price'],axis = 1)

# %%
y_pred_new = lr.predict(X_new)

# %%
y_pred_new
# Out:
# array([33634.94207948])
